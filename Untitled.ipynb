# %% [markdown]
# ## Tried code

# %%
li = "સારું બપોર પછી દરેકને. આભાર પાસે ખૂબ ખૂબ માટે આવતું એક ખૂબ ગરમ સ્વાગત પ્રતિ દરેક આ બપોર પછી. ત્યારથી અમે શરૂ કર્યું હું છું માફ કરશો આ સારું બપોર પછી દરેકને. આભાર પાસે ખૂબ ખૂબ માટે આવતું એક ખૂબ ગરમ સ્વાગત પ્રતિ દરેક આ બપોર પછી. ત્યારથી અમે શરૂ કર્યું હું છું માફ કરશો આ મૂંઝવણ લગભગ સમય તે શરૂ થાય છે છે સારુ પરંતુ ચાલુ કરો અકાળ વિવિયન ડ્રેસ. હું છું આનંદ પ્રતિ સ્વાગત પાસે પ્રતિ એ ઉદ્ઘાટન લંચ. સન્ની પાસે મારા માં મરાઠી ભાષા છે યુનિવર્સિટી ની કેમ્બ્રિજ સ્નાતક અધ્યાપન અંગ્રેજી જેમ કે એક બીજું ભાષા માંથી યુનિવર્સિટી ની લીડ્ઝ એમએસસી અને પીએચડી માં લાગુ કરવું ભાષાશાસ્ત્ર માંથી અહીં એ યુનિવર્સિટી ની એડિનબર્ગ. અને અને ન હતી નિયુક્ત પ્રતિ એક વ્યક્તિ અથવા આતંકવાદી માં શીખવું અંગ્રેજી માટે શૈક્ષણિક હેતુઓ. માં ઓગસ્ટ 2011. ચાઇનીઝ જન્મદિવસ યુનિવર્સિટી માં એ અંગ્રેજી ભાષા અધ્યાપન કેન્દ્ર ત્યારથી 1980. સ્પિનર ચીટ્સ અધ્યાપન પગાર ની એક વરિષ્ઠ વ્યાખ્યાતા અને પ્રોફેસર. તે છે હવે માથું ની એ અંગ્રેજી ટ્રેક અણુ હેતુ વિભાગ. અનિલ આ ભૂમિકા છે જવાબદાર માટે એ યુનિવર્સિટીની ક્યારેય વિસ્તૃત પ્રોગ્રામર ફાઉન્ડેશન 3 સત્ર અને માં સત્ર અભ્યાસક્રમો માટે આંતરરાષ્ટ્રીય વિદ્યાર્થીઓ. આ છે એક અત્યંત મહત્વનું માટે યુનિવર્સિટી ખાસ કરીને જેમ કે એ. આંતરરાષ્ટ્રીય યુનિવર્સિટી. એસ 5 વૈવિધ્યપૂર્ણ એ સંચાર વચ્ચે મૂળ અને બિન-મૂળ સ્પીકર્સ ની અંગ્રેજી માં શૈક્ષણિક સેટિંગ્સ. થ્રેડ ટેલર અધ્યાપન સામગ્રી આધારિત પર મુખ્ય સ્થળ છે જવું માંથી શ્રીમાન શોધો. પ્રજાતિઓ 3 પુસ્તો માટે ભાષા શિક્ષકો માંથી સારું બપોર પછી દરેકને. આભાર પાસે ખૂબ ખૂબ માટે આવતું એક ખૂબ ગરમ સ્વાગત પ્રતિ દરેક આ બપોર પછી. ત્યારથી અમે શરૂ કર્યું હું છું માફ કરશો આ મૂંઝવણ લગભગ સમય તે શરૂ થાય છે છે સારુ પરંતુ ચાલુ કરો અકાળ વિવિયન ડ્રેસ. હું છું આનંદ પ્રતિ સ્વાગત પાસે પ્રતિ એ ઉદ્ઘાટન લંચ. સન્ની પાસે મારા માં મરાઠી ભાષા છે યુનિવર્સિટી ની કેમ્બ્રિજ સ્નાતક અધ્યાપન અંગ્રેજી જેમ કે એક બીજું ભાષા માંથી યુનિવર્સિટી ની લીડ્ઝ એમએસસી અને પીએચડી માં લાગુ કરવું ભાષાશાસ્ત્ર માંથી અહીં એ યુનિવર્સિટી ની એડિનબર્ગ. અને અને ન હતી નિયુક્ત પ્રતિ એક વ્યક્તિ અથવા આતંકવાદી માં શીખવું અંગ્રેજી માટે શૈક્ષણિક હેતુઓ. માં ઓગસ્ટ 2011. ચાઇનીઝ જન્મદિવસ યુનિવર્સિટી માં એ અંગ્રેજી ભાષા અધ્યાપન કેન્દ્ર ત્યારથી 1980. સ્પિનર ચીટ્સ અધ્યાપન પગાર ની એક વરિષ્ઠ વ્યાખ્યાતા અને પ્રોફેસર. તે છે હવે માથું ની એ અંગ્રેજી ટ્રેક અણુ હેતુ વિભાગ. અનિલ આ ભૂમિકા છે જવાબદાર માટે એ યુનિવર્સિટીની ક્યારેય વિસ્તૃત પ્રોગ્રામર ફાઉન્ડેશન 3 સત્ર અને માં સત્ર અભ્યાસક્રમો માટે આંતરરાષ્ટ્રીય વિદ્યાર્થીઓ. આ છે એક અત્યંત મહત્વનું માટે યુનિવર્સિટી ખાસ કરીને જેમ કે એ. આંતરરાષ્ટ્રીય યુનિવર્સિટી. એસ 5 વૈવિધ્યપૂર્ણ એ સંચાર વચ્ચે મૂળ અને બિન-મૂળ સ્પીકર્સ ની અંગ્રેજી માં શૈક્ષણિક સેટિંગ્સ. થ્રેડ ટેલર અધ્યાપન સામગ્રી આધારિત પર મુખ્ય સ્થળ છે જવું માંથી શ્રીમાન શોધો. પ્રજાતિઓ 3 પુસ્તો માટે ભાષા શિક્ષકો માંથી નાસા. સંશોધન 1 કોડ સાંભળવું 1 કોડ અભ્યાસ બોલવું બીજું અભ્યાસ સાંભળવું વાસ્તવિક વાસ્તવિક અસર પર એ અધ્યાપન ની અંગ્રેજી માટે શૈક્ષણિક હેતુઓ. જવાબ મે વેરી દ્વારા ભૌતિકશાસ્ત્ર માં ફિક્સિંગ પર આંતરરાષ્ટ્રીય સ્ટીલ અનૌપચારિક સાંભળવું વ્યૂહરચનાઓ જે છે ઉપલબ્ધ અહીં તે ન હતી લગભગ પ્રતિ એ. જોડણી ભૂલ લાભો ની ફરીથી શરૂ કરવું. વર્ગખંડ સંચાર કાર્ય. સ્વરૂપો ની પ્રતિક્રિયા માં સુધારવું સ્થિતિ માં અંગ્રેજી ખરેખર મહત્વનું વિષયો માટે યુ.એસ. જેમ કે અમે કામ પ્રતિ વિકાસ વિદ્યાર્થી અનુભવ પ્રભુત્વ શીખવું અને અધ્યાપન ચાઇનીઝ હું મહેરબાની કરીને સંમત પ્રતિ જવાબ અમુક પ્રશ્નો અને તેનું જીવન અને પછી ઇચ્છા સ્વાગત પ્રતિ સ્વાગત ઇચ્છા હોવું રાખેલું માં માત્ર બહાર પર એ માળ હું છું કામ કરવું હવે પ્રતિ પ્રોફેસર વાંચન પર એ મહત્વ ની સાંભળવું પ્રતિ આંતરરાષ્ટ્રીય શહેર. પહેલાં મારા ફ્લાઇટ પ્રતિ. સ્વીકારવું એ વ્યાવસાયિકો તે એ અજમાયશ પ્રતિ પ્રતિ સ્ટાફ અંદર યુનિવર્સિટી માં ખાસ સંદર્ભ આળસુ અધ્યાપન સ્ટાફ. પર એ એમ માં શોધ ભૂલો. નં. જૂનું લડાઈ રહસ્યમય જ્યાં હું કર મારો. એમએસસી 1977 અને અનુમાન પ્રતિ ગરમ ઘણાં રંગો કે તબીબી શિક્ષણ. સંસ્થા ની અદ્યતન અભ્યાસ જ્યાં હું કામ કર્યું માટે ઉપર 30 વર્ષો. સાહેબ છે સાંભળવું સમજણ માં એ યુનિવર્સિટી માં ચકાસાયેલ અને ખાસ કરીને. અંગ્રેજી મનસૂરી અનુભવ આંતરરાષ્ટ્રીય ટેબલ. મૂળ સ્પીકર્સ ની અંગ્રેજી ભાષાંતર કરવું માઇક્રો. કરી શકો છો હોવું વાંચવું માં બે માર્ગો શા માટે આ તેથી છે મહત્વનું. માંથી મોઇન્સ આશાવાદી છે મહત્વનું પ્રતિ સાંભળવું પ્રતિ શું તેઓ પાસે પ્રતિ કહેવું લગભગ એ અનુભવ માં ઑક્ટોબર. બૌદ્ધિક ક્ષમતા પર એ પ્રક્રિયાઓ ની આ માં. કેવી રીતે અમે ખબર અનામત. સાંભળવું સમજણ સમસ્યાઓ. વાયરલેસ જન્મેલું સંદેશ તાજી રાષ્ટ્રીય સ્ટીલ સાચવવું એ નવીનતમ હાજરી આપવી સિનેમા અને માર્ગો ની બનાવવું વ્યાખ્યાન વધુ સુલભ પ્રતિ તેમને. યાતાયાત માં માર્ગો સંસાધનો માહિતી તે અમે વાપરવુ ક્યારે મારા પ્રયાસ પ્રતિ સમજવું શું રવિવારે છે સમાન પ્રતિ યુ.એસ. તેથી અમે પાસે ત્રણ સ્તંભ ની જ્ઞાન તે અમે પાસે મર્યાદિત જ્ઞાન માં એમેઝોન અમે પાસે સંદર્ભ. અમે છે. ઇંગલિશ. જ્ઞાન છે તમારા જ્ઞાન ની એ વિષય 16 પ્રતિ તેમને એ સામગ્રી ની એ પ્રથમ છે કેનાબીસ અને લગભગ એ પ્રક્રિયા ની સંચાર વિદ્યાર્થી પર બરફ પ્રતિ સામેલ કરવું એ પરિસ્થિતિ તેથી અને ન હતી કહ્યું તેને જ્યાં અને ક્યારે અને એ મારવું લખાણ તેથી એ અન્ય બિટ્સ ની ભાષા એ પૂર્વ-મોસમ સંપૂર્ણ જો અમે છે હાલમાં સાંભળવું પ્રતિ અને આ પણ એ દ્રષ્ટિ માહિતી તે અમે કરી શકો છો વાપરવુ માં એ શારીરિક સંપર્ક કરવો અને પછી એ તળિયે માં આ સમય અમે પાસે રમી સાથે એક જ્ઞાન ની એક કામચલાઉ. પછી એક કલાક હાથ ની એક સંગઠન યાદી માટે વિદેશી ભાષા છે સંભવતઃ પર એ બોક્સ ની લેગો. જ્યાં છે પાસે નિર્ણય તે છે નહિ પાસે એ શબ્દો એ સ્પીકર છે મદદથી. ક્લિયરિંગ સ્ટ્રાઇકર જેમ કે એક સમસ્યા દ્વારા એ સમાન વસ્તુ લાગુ પડે છે પ્રતિ એક દ્રશ્ય ની તે ભાષા ટ્વિન્સ ટ્વિન્સ પર એ દિવસ મદદથી એક વિવિધતા ની વિદેશી ભાષા સારુ જેમ કે પરિચિત માર્ગો અમે કરી શકો છો પાસે મુશ્કેલી સમજવુ શું એ જણાવ્યું હતું કે ચળવળ ઉદાહરણ અમે રદ કરવું મારા એમએસસી અભ્યાસક્રમ માં 1977 હું ગયા માં એ તબદીલી ની બેંક માં પરફેક્ટ ચોરસ આ છે માં એ દિવસ હું વિચારવું પહેલાં અમે હતી ન હતી માં એ દુનિયા સેવા તપાસ પ્રતિ રોકડ મૂકવું તે માં એ કણક અને એ બેંક ટેલર કહ્યું. કેવી રીતે ઇચ્છા હું આપવું પાસે અમુક પૈસા. નવેસર ચિકિત્સક સમસ્યા ટ્રેન વચ્ચે યુ.એસ. મારા વિઝાર્ડ ન હતી અવરોધિત હું ઇચ્છિત કરવું હું ન હતી વિચારીને શું પ્રતિ કહેવું આકારણી જણાવ્યું હતું કે અમે ઇચ્છિત કરવું પ્રતિ 25 10 તેથી હું ખબર તે આ ન હતી એ પ્રથમ સમય તે હું ન હતી સાવધાન તે અમુક શેરફિશ બોલવું મુલાકાત આ વાપરવુ તે જ્યાં હું ઇચ્છા વાપરવુ કરશે પ્રતિ બનાવવું એક ઓફર પ્રતિ ઓફર એક પસંદગી વિદ્યાર્થી કંપન ની એ સંપર્કો તે છે પૂરતૂ પ્રવેશ સંપર્કો જે સ્થળ નહીં. રો. અને તે છે તમારા પ્રશ્નો અને હું ન હતી જાહેર કરાઈ તાજેતરમાં અને કોઈ પણ ફોર્મ લખાણ પ્રતિ શરૂઆત સાથે સેવા આપવી ખોરાક પ્રતિ એ પ્રશ્ન ચિહ્ન અને આ. તમારા સમસ્યા મનુષ્ય માણસો પ્રતિ તમારા સમસ્યા શોધો એ માર્ગ પ્રતિ સંપર્ક કરવો હું તે બનાવે છે સેન્સ. નાગિન 4. વિક્રામ સેક્સી જાન્યુઆરી. શિક્ષણ કાર્ડ અર્થ. સક્રિય સેન્સર કેમેરા અને પદ્ધતિ સેવા તપાસ માં મારા માલ પ્રતિ યુ.એસ. પ્રશ્ન. પ્રશ્ન શું છે વિકસિત. સરસવ ચહેરો પ્રતિ અર્થ કંઈક જેમ શું પાસે ફરી તેથી હું વિચારવું હું ઇચ્છું છું પૂર્ણ કંઈક ખોટું પરંતુ તે નથી લાગતું પ્રતિ ફિટ માં સાથે આ હું છું મોકલીને બહાર વધુ સંદર્ભ. કરવું સિસ્ટમો ન હતી ભારતીય. પિતા તેથી ની તેનું જીવન. અને સાહેબ હું કહ્યું. અનિવાર્યપણે એ સમાન વસ્તુ આ સમય અહીં તે છે એ વિશેષજ્ઞ બ્રિટીશ શું છે બ્રિટીશ સમય છે આ બિંદુ હું છું ના યોજનાકીય જ્ઞાન પ્રતિ પાછા બ્રિટીશ વસાહતી ઇતિહાસ. લાત માં એ ટ્રેન રમત. માં એ દુનિયા યુ ટ્યુબ અને જણાવ્યું હતું કે હું છું માફ કરશો હું નથી સમજવું. આ સમય. તે ઉછેર તેનું ભમર ન્યાય સહાય પ્રતિ માં મારા શોપિંગ અને જણાવ્યું હતું કે શું છે બ્રિટીશ કેન્સર. નવેમ્બર એકવીસ. હોડી ન હતી એક કાસલ મિકસ. જીવવું બ્રિટીશ સમય હું ઇચ્છા જવાબ પ્રશ્ન અને 4. મુખ્ય માહિતી લગભગ તે ન હતી શિક્ષકો પુતિરી રિચાર્જ ઓફર એ પ્રક્રિયા લીધેલું લગભગ બે તાજેતરના ઉદાહરણ ની રુટ તે અમે લો. ક્યારે પ્રયાસ પ્રતિ બનાવવું અર્થ ની નુકસાન ની એ દિવસ પાસે જંગલ અમે ખરેખર આપવું સીધી માંથી અમારું જ્ઞાન પ્રતિ સમજ. અમે વાપરવુ આવક કરવેરા ભાષા અને અસર નિયમનકારી શફલ તે ન હતી લાદેલું કેન્દ્ર બોલવું વચ્ચે એ વિભિન્ન સ્ત્રોતો અને અમે પ્રયત્ન કરવો પ્રતિ પ્રતિ બનાવવું સેન્સ. વિજેતા ની એ રિંગ્સ સાથે તંગ અને ઓછું છે અમુક સૉર્ટ કરો ની અવરોધ આવા જેમ કે તે બનવું માં એક વિદેશી ભાષા. બનાવવું સજા ની એ નિર્ણય છે એ માર્ગ મારો. વલણ છબીઓ ખંડ પ્રતિ રહેવું તે અમે પાસે પ્રતિ કરવું આ. માં સમાંતર બહાર અને તરત. ભાષણ ની વિદેશી ભાષા છે મોકલવું તે સલામત પ્રતિ ના પાડવી રજા એ પ્રેમી. "

# %%
#pip install -e git+https://github.com/webpy/webpy.git#egg=webpy

# %%
pip install pytest
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.0/297.0 KB 779.4 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
with open("audio2.txt","r") as a:
    ab = a.read()

# %%
c = ab.split(".")

# %%
from translate import Translator
import time

# %%
len(c)
# Out:
# 831

# %%
def fun3(b):
    translator= Translator(to_lang="Gujarati")
    translation = translator.translate(b)
    #print(translation)
    return translation

# %%
with open("audio3-guj.txt","a") as file1:
    for i in c:
        print(i)
        file1.write(fun3(i))
        time.sleep(10)
# Out:
# Good afternoon everyone
#  Thank you very much for coming a very warm welcome to everyone this afternoon
#  Since we started
#  I am sorry this confusion about time it starts is well but turn
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/translate/translate.py in <genexpr>(.0)
#      44         text_list = wrap(text, TRANSLATION_API_MAX_LENGHT, replace_whitespace=False)
# ---> 45         return ' '.join(self.provider.get_translation(text_wraped) for text_wraped in text_list)
#
# ~/anaconda3/lib/python3.9/site-packages/translate/providers/mymemory_translated.py in get_translation(self, text)
#      48             matches = data['matches']
# ---> 49             next_best_match = next(match for match in matches)
#      50             return next_best_match['translation']
#
# StopIteration:
#
# ...

# %%
#GFG
# Import the required module for text 
# to speech conversion
from gtts import gTTS
# This module is imported so that we can 
# play the converted audio
import os

# %%
with open("audio2-guj.txt","r") as fil2:
    a = fil2.read()

# %%
a
# Out:
# 'શુભ બપોર દરેક આ બપોરે દરેકને ખૂબ જ ગરમ સ્વાગત કરવા બદલ ખુબ ખુબ આભાર કારણ કે અમે શરૂ કર્યું હું માફ કરું છું કે આ મૂંઝવણ તે સમયથી શરૂ થાય છે તે સારી છે પરંતુ ચાલુ થાય છે અકાળ વિવિયન ડેસના મને ઉદ્ઘાટન બપોરના ભોજનમાં આપનું સ્વાગત છે સન્ની મારી મરાઠી ભાષામાં કેમ્બ્રિજ ગ્રેજ્યુએટ અધ્યયન ઇંગલિશ યુનિવર્સિટી ઓફ લીડ્ઝ યુનિવર્સિટીની બીજી ભાષા છે એડિનબર્ગ યુનિવર્સિટીમાંથી એપ્લાઇડ ભાષાશાસ્ત્રમાં એમએસસી અને પીએચડી અને તેને શૈક્ષણિક હેતુઓ માટે અંગ્રેજી શીખવામાં વ્યક્તિ અથવા આતંકવાદીને નિયુક્ત કરવામાં આવ્યા હતા ઑગસ્ટ 2011 માં 1980 થી ઇંગલિશ ભાષા અધ્યાપન કેન્દ્રમાં ચિની જન્મદિવસ યુનિવર્સિટી સ્પિનર એ વરિષ્ઠ લેક્ચરર અને પ્રોફેસરના શિક્ષણ પગાર શીખવે છે તે હવે ઇંગલિશ ટ્રેક પરમાણુ હેતુ વિભાગના વડા છે અનિલ આ ભૂમિકા યુનિવર્સિટીના ક્યારેય વિસ્તૃત પ્રોગ્રામર ફાઉન્ડેશન 3 સત્ર અને આંતરરાષ્ટ્રીય વિદ્યાર્થીઓ માટે સત્ર અભ્યાસક્રમો માટે જવાબદાર છે આ યુનિવર્સિટી માટે ખાસ કરીને એક અત્યંત મહત્વપૂર્ણ છે આંતરરાષ્ટ્રીય યુનિવર્સિટી એસ 5 ને શૈક્ષણિક સેટિંગ્સમાં અંગ્રેજીના મૂળ અને બિન-મૂળ બોલનારા વચ્ચેના સંચાર મુખ્ય સાઇટ 
# ...

# %%
# The text that you want to convert to audio
#mytext = translate_text
#print(translate_text)
# Language in which you want to convert
language = 'gu'
  
# Passing the text and language to the engine, 
# here we have marked slow=False. Which tells 
# the module that the converted audio should 
# have a high speed
myobj = gTTS(text=a, lang=language, slow=False)
  
# Saving the converted audio in a mp3 file named
# welcome 
myobj.save("welcome2.mp3")
  
# Playing the converted file
os.system("mpg321 welcome2.mp3")
